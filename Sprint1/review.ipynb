# %%
using System;
using System.Collections.Generic;

public class Product
{
    private string name;
    private decimal price;
    private int quantity;
    protected string category;
    internal string description;

    public Product(string name, string description, string category, int quantity, decimal price)
    {
        this.name = name;
        this.price = price;
        this.quantity = quantity;
        this.category = category;
        this.description = description;
    }

    public decimal Price
    {
        get {return price;}
        set {price = value;}
    }

    public string Name
    {
        get {return name;}
        set {name = value;}
    }

    public string Category
    {
        get {return category;}
        set {category = value;}
    }

    public int Quantity
    {
        get {return quantity;}
        set {quantity = value;}
    }

    public string Description
    {
        get {return description;}
        set {description = value;}
    }

    public decimal GetTotalPrice()
    {
        return price * quantity;
    }

    public void UpdateQuantity(int amount)
    {
        quantity += amount;
    }

    public string GetProductInfo()
    {
        return $"Товар: {name}, Описание: {description}, Категория: {category}, Количество: {quantity}, Цена: {price} р";
    }
}

public class Seller
{
    private string name;
    private string employeeId;
    protected decimal salary;
    internal string contactInfo;
    private List<Product> products = new List<Product>();

    public Seller(string name, string employeeId, decimal salary, string contactInfo)
    {
        this.name = name;
        this.employeeId = employeeId;
        this.salary = salary;
        this.contactInfo = contactInfo;
    }

    public string Name
    {
        get { return name; }
        set { name = value; }
    }

    public string EmployeeId
    {
        get { return employeeId; }
        set { employeeId = value; }
    }

    public decimal Salary
    {
        get { return salary; }
        set { salary = value; }
    }

    public string ContactInfo
    {
        get { return contactInfo; }
        internal set { contactInfo = value; }
    }

    public void AddProduct(Product product)
    {
        products.Add(product);
    }

    public void SellProduct(Product product, int quantity)
    {
        if (products.Contains(product) && product.Quantity >= quantity)
        {
            product.UpdateQuantity(-quantity);
            Console.WriteLine($"{name} продал(а) {quantity} шт. товара {product.Name}");
        }
        else
        {
            Console.WriteLine("Недостаточно товара на складе или товар не найден.");
        }
    }

    public string GetSellerInfo()
    {
        return $"Продавец: {name}, Id: {employeeId}, Зарплата: {salary} р, Контакты: {contactInfo}";
    }

    public List<Product> GetProducts()
    {
        return products;
    }
}

public class Store
{
    private string storeName;
    private string location;
    public string storeHours;
    private List<Seller> sellers = new List<Seller>();

    public Store(string storeName, string location, string storeHours)
    {
        this.storeName = storeName;
        this.location = location;
        this.storeHours = storeHours;
    }

    public string StoreName
    {
        get { return storeName; }
        set { storeName = value; }
    }

    public string Location
    {
        get { return location; }
        set { location = value; }
    }

    public void AddSeller(Seller seller)
    {
        sellers.Add(seller);
    }

    public void ListProducts()
    {
        Console.WriteLine($"Товары в магазине {storeName}:");
        foreach (var seller in sellers)
        {
            foreach (var product in seller.GetProducts())
            {
                Console.WriteLine(product.GetProductInfo());
            }
        }
    }

    public string GetStoreInfo()
    {
        return $"Магазин: {storeName}, Адрес: {location}, Время работы: {storeHours}";
    }
}

Product posuda = new Product("Посудомойка BORK", "Удобная, качественная посудомойка", "Электроника",15, 99900);
Seller prodavec = new Seller("Геннадий", "RGV230706", 69000, "+79292672307");
Store MVideo = new Store("Мвидео", "ул. Дмитрия Менделеева, 1а", "10:00-22:00");

prodavec.AddProduct(posuda);
MVideo.AddSeller(prodavec);

Console.WriteLine(posuda.GetProductInfo());
Console.WriteLine(prodavec.GetSellerInfo());
Console.WriteLine(MVideo.GetStoreInfo());

prodavec.SellProduct(posuda, 7);
MVideo.ListProducts();
# Out:
# Товар: Посудомойка BORK, Описание: Удобная, качественная посудомойка, Категория: Электроника, Количество: 15, Цена: 99900 р
# Продавец: Геннадий, Id: RGV230706, Зарплата: 69000 р, Контакты: +79292672307
# Магазин: Мвидео, Адрес: ул. Дмитрия Менделеева, 1а, Время работы: 10:00-22:00
# Геннадий продал(а) 7 шт. товара Посудомойка BORK
# Товары в магазине Мвидео:
# Товар: Посудомойка BORK, Описание: Удобная, качественная посудомойка, Категория: Электроника, Количество: 8, Цена: 99900 р
